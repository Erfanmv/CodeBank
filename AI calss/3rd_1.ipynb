# %%
import pandas as pd 
df =  pd.read_csv("E:\\AI calss\data1.csv")
df
# Out:
#     name windows  internet
# 0    ali      18      20.0
# 1  samin       -      14.0
# 2   reza      12      15.0
# 3  mamad      20       NaN

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of     name windows  internet
# 0    ali      18      20.0
# 1  samin       -      14.0
# 2   reza      12      15.0
# 3  mamad      20       NaN>

# %%
df.describe()
# Out:
#         internet
# count   3.000000
# mean   16.333333
# std     3.214550
# min    14.000000
# 25%    14.500000
# 50%    15.000000
# 75%    17.500000
# max    20.000000

# %%
df.columns
# Out:
# Index(['name', 'windows', 'internet'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.read_csv("data1.csv",index_col = 'name')
df.set_index('name',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\AI calss\3rd_1.ipynb Cell 6 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/AI%20calss/3rd_1.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # df = pd.read_csv("data1.csv",index_col = 'name')
# ----> <a href='vscode-notebook-cell:/e%3A/AI%20calss/3rd_1.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> df.set_index('name',inplace=True)
#       <a href='vscode-notebook-cell:/e%3A/AI%20calss/3rd_1.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> df
#
# File c:\Users\erfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
df['windows']
# Out:
# name
# ali      18
# samin     -
# reza     12
# mamad    20
# Name: windows, dtype: object

# %%
df['windows']['ali']
# Out:
# '18'

# %%
df.loc['ali']
# Out:
# windows       18
# internet    20.0
# Name: ali, dtype: object

# %%
df.loc[['ali','samin']]
# Out:
#       windows  internet
# name
# ali        18      20.0
# samin       -      14.0

# %%
df['windows']['ali':'reza']
# Out:
# name
# ali      18
# samin     -
# reza     12
# Name: windows, dtype: object

# %%
personlist=[{'name':'ahmad','id':1},
           {"name":'reza','id':2},
           {"name":'ali','id':3}]
df=pd.DataFrame(personlist)
df
# Out:
#     name  id
# 0  ahmad   1
# 1   reza   2
# 2    ali   3

# %%
df = pd.DataFrame()
df['temp'] = [10,20,30]
df
# Out:
#    temp
# 0    10
# 1    20
# 2    30

# %%
df =  pd.read_csv('BTC-USD.csv')
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2022-05-11  31016.183594  32013.402344  28170.414063  28936.355469
# 1    2022-05-12  28936.734375  30032.439453  26350.490234  29047.751953
# 2    2022-05-13  29030.910156  30924.802734  28782.330078  29283.103516
# 3    2022-05-14  29285.642578  30192.802734  28702.910156  30101.265625
# 4    2022-05-15  30098.585938  31308.191406  29527.740234  31305.113281
# ..          ...           ...           ...           ...           ...
# 361  2023-05-07  28901.623047  29157.517578  28441.367188  28454.978516
# 362  2023-05-08  28450.457031  28663.271484  27310.134766  27694.273438
# 363  2023-05-09  27695.068359  27821.400391  27375.601563  27658.775391
# 364  2023-05-10  27654.636719  28322.687500  26883.669922  27621.755859
# 365  2023-05-11  27618.919922  27621.716797  27055.189453  27200.123047
#
#         Adj Close       Volume
# 0    28936.355469  70388855818
# 1    29047.751953  66989173272
# ...

# %%
df.head(15)
# Out:
#           Date          Open          High           Low         Close  \
# 0   